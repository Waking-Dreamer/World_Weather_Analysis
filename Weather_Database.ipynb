# %% [markdown]
# # Part 1
# ## Get the Weather Description and Amount of Precipitation for Each City

# %%
# Import dependencies
import numpy as np
from citipy import citipy
import requests
import pandas as pd

# Import the wheather API key.
from config import api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=1500)
lngs = np.random.uniform(-180,180, size=1500)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Starting URL for Weather Map API Call.
# units=Imperial added to url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather["weather"][0]["description"]
        try:
            city_rain_fall = city_weather["rain"]["1h"]
        except(KeyError):
            city_rain_fall = 0
        try:
            city_snow_fall= city_weather["snow"]["1h"]
        except(KeyError):
            city_snow_fall = 0
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descrip,
                          "Rain (inches)": city_rain_fall,
                          "Snow (inches)": city_snow_fall})
                          
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | ozernovskiy
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | atkinson
# Processing Record 5 of Set 1 | cozma
# Processing Record 6 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | emerald
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | codrington
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | voorst
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | tshela
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | iralaya
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | kailua
# Processing Record 28 of Set 1 | tateyama
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | luganville
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | hami
# Processing Record 38 of Set 1 | portland
# Processing Record 39 of Set 1 | yarada
# Processing Record 40 of Set 1 | caravelas
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | paita
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | aksarka
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | colchester
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | derzhavinsk
# Processing Record 3 of Set 2 | lompoc
# Processing Record 4 of Set 2 | hay river
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | qaqortoq
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 2 | alofi
# Processing Record 12 of Set 2 | isangel
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | manaus
# Processing Record 16 of Set 2 | virginia beach
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | aksu
# Processing Record 19 of Set 2 | abu kamal
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | salgueiro
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | udachnyy
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | ranau
# Processing Record 26 of Set 2 | barreirinhas
# Processing Record 27 of Set 2 | jacksonville
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | bandarbeyla
# Processing Record 30 of Set 2 | kovdor
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | dunedin
# Processing Record 37 of Set 2 | baghdad
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | krasnoselkup
# Processing Record 41 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 42 of Set 2 | moerai
# Processing Record 43 of Set 2 | camacha
# Processing Record 44 of Set 2 | mount gambier
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | ahuimanu
# Processing Record 48 of Set 2 | kavaratti
# Processing Record 49 of Set 2 | nieuw nickerie
# Processing Record 50 of Set 2 | ancud
# Processing Record 1 of Set 3 | port lincoln
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | merauke
# Processing Record 4 of Set 3 | gazli
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | majene
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 3 | fukue
# Processing Record 10 of Set 3 | san ignacio
# Processing Record 11 of Set 3 | dwarka
# Processing Record 12 of Set 3 | constitucion
# Processing Record 13 of Set 3 | turukhansk
# Processing Record 14 of Set 3 | cuamba
# Processing Record 15 of Set 3 | licheng
# Processing Record 16 of Set 3 | umba
# Processing Record 17 of Set 3 | acapulco
# Processing Record 18 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | magistralnyy
# Processing Record 21 of Set 3 | sovetskiy
# Processing Record 22 of Set 3 | tazmalt
# Processing Record 23 of Set 3 | ilesha
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | port augusta
# Processing Record 26 of Set 3 | sobolevo
# Processing Record 27 of Set 3 | igrim
# Processing Record 28 of Set 3 | disna
# Processing Record 29 of Set 3 | erbaa
# Processing Record 30 of Set 3 | san quintin
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | benicarlo
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | ust-nera
# Processing Record 37 of Set 3 | castelo do piaui
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | tomelloso
# Processing Record 41 of Set 3 | oistins
# Processing Record 42 of Set 3 | bilma
# Processing Record 43 of Set 3 | san nicolas
# Processing Record 44 of Set 3 | papar
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | mamakan
# Processing Record 47 of Set 3 | morrope
# Processing Record 48 of Set 3 | umm lajj
# Processing Record 49 of Set 3 | asyut
# Processing Record 50 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 4 | yahotyn
# Processing Record 2 of Set 4 | salinopolis
# Processing Record 3 of Set 4 | leh
# Processing Record 4 of Set 4 | kyshtovka
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | america dourada
# Processing Record 7 of Set 4 | vila
# Processing Record 8 of Set 4 | puerto escondido
# Processing Record 9 of Set 4 | coahuayana
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | olafsvik
# Processing Record 13 of Set 4 | sioux lookout
# Processing Record 14 of Set 4 | marsa matruh
# Processing Record 15 of Set 4 | klaksvik
# Processing Record 16 of Set 4 | comodoro rivadavia
# Processing Record 17 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 4 | sol-iletsk
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | new norfolk
# Processing Record 23 of Set 4 | juneau
# Processing Record 24 of Set 4 | yumen
# Processing Record 25 of Set 4 | ibra
# Processing Record 26 of Set 4 | taozhuang
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | saint-augustin
# Processing Record 29 of Set 4 | adrar
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | buy
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | pimentel
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | ortigueira
# Processing Record 37 of Set 4 | mahibadhoo
# Processing Record 38 of Set 4 | abbeville
# Processing Record 39 of Set 4 | wahiawa
# Processing Record 40 of Set 4 | fez
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | beya
# Processing Record 43 of Set 4 | rondonopolis
# Processing Record 44 of Set 4 | rockland
# Processing Record 45 of Set 4 | dingle
# Processing Record 46 of Set 4 | mouzouras
# Processing Record 47 of Set 4 | vao
# Processing Record 48 of Set 4 | hilo
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | springbok
# Processing Record 1 of Set 5 | newala
# Processing Record 2 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 5 | quelimane
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | lahaina
# Processing Record 6 of Set 5 | kahului
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | bitung
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | neiafu
# Processing Record 11 of Set 5 | altay
# Processing Record 12 of Set 5 | port-gentil
# Processing Record 13 of Set 5 | aykhal
# Processing Record 14 of Set 5 | kattivakkam
# Processing Record 15 of Set 5 | khash
# Processing Record 16 of Set 5 | lishu
# Processing Record 17 of Set 5 | calabozo
# Processing Record 18 of Set 5 | along
# Processing Record 19 of Set 5 | kyaikto
# Processing Record 20 of Set 5 | ruian
# City not found. Skipping...
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | kodiak
# Processing Record 23 of Set 5 | urumqi
# Processing Record 24 of Set 5 | tacoronte
# Processing Record 25 of Set 5 | yima
# Processing Record 26 of Set 5 | lang suan
# Processing Record 27 of Set 5 | opuwo
# Processing Record 28 of Set 5 | lida
# Processing Record 29 of Set 5 | selikhino
# Processing Record 30 of Set 5 | sambava
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | popondetta
# Processing Record 33 of Set 5 | thinadhoo
# Processing Record 34 of Set 5 | raudeberg
# Processing Record 35 of Set 5 | vila velha
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | kargil
# Processing Record 38 of Set 5 | praia
# Processing Record 39 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 40 of Set 5 | wattegama
# Processing Record 41 of Set 5 | ascension
# Processing Record 42 of Set 5 | weligama
# Processing Record 43 of Set 5 | nova ushytsya
# Processing Record 44 of Set 5 | sola
# Processing Record 45 of Set 5 | sinnamary
# Processing Record 46 of Set 5 | tabulbah
# City not found. Skipping...
# Processing Record 47 of Set 5 | taoudenni
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | pine bluff
# Processing Record 50 of Set 5 | pisco
# Processing Record 1 of Set 6 | savonlinna
# Processing Record 2 of Set 6 | osa
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | kalianget
# Processing Record 5 of Set 6 | khanewal
# Processing Record 6 of Set 6 | qaanaaq
# Processing Record 7 of Set 6 | sao domingos
# Processing Record 8 of Set 6 | ambovombe
# Processing Record 9 of Set 6 | shahrud
# Processing Record 10 of Set 6 | tambacounda
# Processing Record 11 of Set 6 | nelson bay
# Processing Record 12 of Set 6 | tiksi
# Processing Record 13 of Set 6 | vysokogornyy
# Processing Record 14 of Set 6 | djougou
# Processing Record 15 of Set 6 | macklin
# Processing Record 16 of Set 6 | miracema do tocantins
# Processing Record 17 of Set 6 | amahai
# Processing Record 18 of Set 6 | thompson
# Processing Record 19 of Set 6 | tomatlan
# Processing Record 20 of Set 6 | hovd
# Processing Record 21 of Set 6 | el tocuyo
# Processing Record 22 of Set 6 | tabas
# Processing Record 23 of Set 6 | egvekinot
# Processing Record 24 of Set 6 | turka
# Processing Record 25 of Set 6 | husavik
# Processing Record 26 of Set 6 | thanh hoa
# Processing Record 27 of Set 6 | kitimat
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | lorengau
# Processing Record 30 of Set 6 | lewisporte
# Processing Record 31 of Set 6 | brewster
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | cidreira
# Processing Record 34 of Set 6 | san carlos de bariloche
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | lata
# Processing Record 38 of Set 6 | parrita
# Processing Record 39 of Set 6 | abu zabad
# Processing Record 40 of Set 6 | baturaja
# Processing Record 41 of Set 6 | ponta do sol
# Processing Record 42 of Set 6 | omboue
# Processing Record 43 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | te anau
# Processing Record 45 of Set 6 | mozarlandia
# Processing Record 46 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 6 | palauig
# Processing Record 48 of Set 6 | calvinia
# Processing Record 49 of Set 6 | soe
# Processing Record 50 of Set 6 | berlevag
# Processing Record 1 of Set 7 | wanderlandia
# City not found. Skipping...
# Processing Record 2 of Set 7 | cleveland
# Processing Record 3 of Set 7 | pacific grove
# Processing Record 4 of Set 7 | shimoda
# Processing Record 5 of Set 7 | buchanan
# Processing Record 6 of Set 7 | baruun-urt
# Processing Record 7 of Set 7 | mizdah
# Processing Record 8 of Set 7 | kokologo
# Processing Record 9 of Set 7 | crestview
# Processing Record 10 of Set 7 | walvis bay
# Processing Record 11 of Set 7 | freeport
# Processing Record 12 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 7 | aberystwyth
# Processing Record 14 of Set 7 | san policarpo
# Processing Record 15 of Set 7 | tigil
# Processing Record 16 of Set 7 | mirador
# Processing Record 17 of Set 7 | singleton
# Processing Record 18 of Set 7 | pueblo nuevo
# Processing Record 19 of Set 7 | socorro
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | baisha
# Processing Record 22 of Set 7 | winchester
# Processing Record 23 of Set 7 | chiredzi
# Processing Record 24 of Set 7 | basco
# Processing Record 25 of Set 7 | coihaique
# Processing Record 26 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 7 | auki
# Processing Record 28 of Set 7 | santarem
# Processing Record 29 of Set 7 | staritsa
# Processing Record 30 of Set 7 | kungurtug
# Processing Record 31 of Set 7 | santo tomas
# Processing Record 32 of Set 7 | madison heights
# Processing Record 33 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 7 | hamilton
# Processing Record 35 of Set 7 | mouila
# Processing Record 36 of Set 7 | miri
# Processing Record 37 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 7 | ostrovnoy
# Processing Record 39 of Set 7 | ambilobe
# Processing Record 40 of Set 7 | kommunisticheskiy
# Processing Record 41 of Set 7 | sulangan
# Processing Record 42 of Set 7 | innisfail
# Processing Record 43 of Set 7 | trincomalee
# Processing Record 44 of Set 7 | la ciotat
# Processing Record 45 of Set 7 | nador
# Processing Record 46 of Set 7 | asau
# Processing Record 47 of Set 7 | sri aman
# Processing Record 48 of Set 7 | saint-leu
# Processing Record 49 of Set 7 | marystown
# Processing Record 50 of Set 7 | cascais
# Processing Record 1 of Set 8 | patnos
# Processing Record 2 of Set 8 | srandakan
# Processing Record 3 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 8 | khani
# Processing Record 5 of Set 8 | prince rupert
# Processing Record 6 of Set 8 | sindou
# Processing Record 7 of Set 8 | torbay
# Processing Record 8 of Set 8 | abu samrah
# Processing Record 9 of Set 8 | francisco beltrao
# Processing Record 10 of Set 8 | oneida
# Processing Record 11 of Set 8 | havoysund
# Processing Record 12 of Set 8 | shache
# Processing Record 13 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 8 | cariati
# Processing Record 15 of Set 8 | kastamonu
# Processing Record 16 of Set 8 | imbituba
# Processing Record 17 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 8 | matara
# Processing Record 20 of Set 8 | katsuura
# Processing Record 21 of Set 8 | kulhudhuffushi
# Processing Record 22 of Set 8 | ballina
# Processing Record 23 of Set 8 | teguldet
# Processing Record 24 of Set 8 | grindavik
# Processing Record 25 of Set 8 | bonthe
# Processing Record 26 of Set 8 | oktyabrskiy
# Processing Record 27 of Set 8 | amboasary
# Processing Record 28 of Set 8 | topchanchi
# Processing Record 29 of Set 8 | bamnet narong
# Processing Record 30 of Set 8 | atambua
# Processing Record 31 of Set 8 | pevek
# Processing Record 32 of Set 8 | kapoeta
# Processing Record 33 of Set 8 | maltahohe
# Processing Record 34 of Set 8 | itaueira
# Processing Record 35 of Set 8 | kieta
# Processing Record 36 of Set 8 | yerbogachen
# Processing Record 37 of Set 8 | santa maria
# Processing Record 38 of Set 8 | colquechaca
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | margate
# Processing Record 41 of Set 8 | victoria
# Processing Record 42 of Set 8 | makakilo city
# Processing Record 43 of Set 8 | honningsvag
# Processing Record 44 of Set 8 | hambantota
# Processing Record 45 of Set 8 | faya
# Processing Record 46 of Set 8 | gillette
# Processing Record 47 of Set 8 | panlaitan
# Processing Record 48 of Set 8 | adre
# Processing Record 49 of Set 8 | avera
# Processing Record 50 of Set 8 | santa cruz
# Processing Record 1 of Set 9 | aklavik
# Processing Record 2 of Set 9 | vanavara
# Processing Record 3 of Set 9 | leshukonskoye
# Processing Record 4 of Set 9 | nova vicosa
# Processing Record 5 of Set 9 | saint anthony
# Processing Record 6 of Set 9 | bani
# Processing Record 7 of Set 9 | safaga
# Processing Record 8 of Set 9 | abaza
# Processing Record 9 of Set 9 | saurimo
# Processing Record 10 of Set 9 | college
# Processing Record 11 of Set 9 | yar-sale
# Processing Record 12 of Set 9 | sept-iles
# Processing Record 13 of Set 9 | umm kaddadah
# Processing Record 14 of Set 9 | lewistown
# Processing Record 15 of Set 9 | soyo
# Processing Record 16 of Set 9 | dhidhdhoo
# Processing Record 17 of Set 9 | korla
# Processing Record 18 of Set 9 | kaduna
# Processing Record 19 of Set 9 | kirgiz-miyaki
# Processing Record 20 of Set 9 | bay roberts
# Processing Record 21 of Set 9 | pochutla
# Processing Record 22 of Set 9 | vardo
# Processing Record 23 of Set 9 | chicama
# Processing Record 24 of Set 9 | svetlogorsk
# Processing Record 25 of Set 9 | conde
# Processing Record 26 of Set 9 | coos bay
# Processing Record 27 of Set 9 | zhuhai
# Processing Record 28 of Set 9 | the valley
# Processing Record 29 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 9 | lagoa
# Processing Record 31 of Set 9 | bagotville
# Processing Record 32 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 33 of Set 9 | peterhead
# Processing Record 34 of Set 9 | dakar
# Processing Record 35 of Set 9 | necochea
# Processing Record 36 of Set 9 | kuryk
# Processing Record 37 of Set 9 | deputatskiy
# Processing Record 38 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 9 | tual
# Processing Record 40 of Set 9 | biak
# Processing Record 41 of Set 9 | mulege
# Processing Record 42 of Set 9 | kasongo-lunda
# Processing Record 43 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 9 | port blair
# Processing Record 45 of Set 9 | corn island
# Processing Record 46 of Set 9 | port hardy
# Processing Record 47 of Set 9 | mont-dore
# Processing Record 48 of Set 9 | trat
# Processing Record 49 of Set 9 | lavrentiya
# Processing Record 50 of Set 9 | zyryanovsk
# Processing Record 1 of Set 10 | zhezkazgan
# Processing Record 2 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 10 | paragominas
# Processing Record 4 of Set 10 | vestmannaeyjar
# Processing Record 5 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 10 | luanda
# Processing Record 7 of Set 10 | baiyin
# Processing Record 8 of Set 10 | banjarmasin
# Processing Record 9 of Set 10 | vostok
# Processing Record 10 of Set 10 | anadyr
# Processing Record 11 of Set 10 | eguia
# Processing Record 12 of Set 10 | ugoofaaru
# Processing Record 13 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 10 | kirkwall
# Processing Record 15 of Set 10 | sakakah
# Processing Record 16 of Set 10 | sale
# Processing Record 17 of Set 10 | san-pedro
# Processing Record 18 of Set 10 | dibrugarh
# Processing Record 19 of Set 10 | buraydah
# Processing Record 20 of Set 10 | havre-saint-pierre
# Processing Record 21 of Set 10 | mount isa
# Processing Record 22 of Set 10 | sanandaj
# Processing Record 23 of Set 10 | vikhorevka
# Processing Record 24 of Set 10 | robertson
# Processing Record 25 of Set 10 | hervey bay
# Processing Record 26 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 10 | mandera
# Processing Record 28 of Set 10 | san antonio
# Processing Record 29 of Set 10 | solnechnyy
# Processing Record 30 of Set 10 | faranah
# Processing Record 31 of Set 10 | perevoz
# Processing Record 32 of Set 10 | coquimbo
# Processing Record 33 of Set 10 | trairi
# Processing Record 34 of Set 10 | eureka
# Processing Record 35 of Set 10 | talaya
# Processing Record 36 of Set 10 | half moon bay
# Processing Record 37 of Set 10 | doka
# Processing Record 38 of Set 10 | churapcha
# Processing Record 39 of Set 10 | spring valley
# Processing Record 40 of Set 10 | kuching
# Processing Record 41 of Set 10 | sao felix do xingu
# Processing Record 42 of Set 10 | leningradskiy
# Processing Record 43 of Set 10 | san cristobal
# Processing Record 44 of Set 10 | sabang
# Processing Record 45 of Set 10 | kenai
# Processing Record 46 of Set 10 | general pico
# Processing Record 47 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 10 | shelburne
# Processing Record 49 of Set 10 | borgo san dalmazzo
# Processing Record 50 of Set 10 | pozo colorado
# Processing Record 1 of Set 11 | puerto carreno
# Processing Record 2 of Set 11 | clyde river
# Processing Record 3 of Set 11 | bauska
# Processing Record 4 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 5 of Set 11 | marzuq
# Processing Record 6 of Set 11 | wajir
# Processing Record 7 of Set 11 | saint-georges
# Processing Record 8 of Set 11 | rockport
# Processing Record 9 of Set 11 | mehamn
# Processing Record 10 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 11 | matamoros
# Processing Record 12 of Set 11 | santa cruz del sur
# Processing Record 13 of Set 11 | barinas
# Processing Record 14 of Set 11 | hit
# Processing Record 15 of Set 11 | majalgaon
# Processing Record 16 of Set 11 | yankton
# Processing Record 17 of Set 11 | nicoya
# Processing Record 18 of Set 11 | plainview
# Processing Record 19 of Set 11 | sorland
# Processing Record 20 of Set 11 | beringovskiy
# Processing Record 21 of Set 11 | tura
# Processing Record 22 of Set 11 | kostomuksha
# Processing Record 23 of Set 11 | brive-la-gaillarde
# Processing Record 24 of Set 11 | los llanos de aridane
# Processing Record 25 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 11 | kaka
# Processing Record 27 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 28 of Set 11 | bam
# Processing Record 29 of Set 11 | neuquen
# Processing Record 30 of Set 11 | zhigansk
# Processing Record 31 of Set 11 | solvychegodsk
# Processing Record 32 of Set 11 | westport
# Processing Record 33 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 34 of Set 11 | lucea
# Processing Record 35 of Set 11 | imeni babushkina
# Processing Record 36 of Set 11 | muzhi
# Processing Record 37 of Set 11 | mogadishu
# Processing Record 38 of Set 11 | qinhuangdao
# Processing Record 39 of Set 11 | preobrazheniye
# Processing Record 40 of Set 11 | hobyo
# Processing Record 41 of Set 11 | bandundu
# Processing Record 42 of Set 11 | namatanai
# Processing Record 43 of Set 11 | ankang
# Processing Record 44 of Set 11 | porto walter
# Processing Record 45 of Set 11 | madimba
# Processing Record 46 of Set 11 | voznesenskoye
# Processing Record 47 of Set 11 | laela
# Processing Record 48 of Set 11 | pervomayskiy
# Processing Record 49 of Set 11 | quatre cocos
# Processing Record 50 of Set 11 | dera bugti
# Processing Record 1 of Set 12 | zhirnovsk
# Processing Record 2 of Set 12 | kununurra
# Processing Record 3 of Set 12 | vila do maio
# Processing Record 4 of Set 12 | palamos
# Processing Record 5 of Set 12 | maymyo
# Processing Record 6 of Set 12 | wilmington
# Processing Record 7 of Set 12 | banda aceh
# Processing Record 8 of Set 12 | concordia
# Processing Record 9 of Set 12 | romny
# Processing Record 10 of Set 12 | tvoroyri
# Processing Record 11 of Set 12 | male
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | yomou
# Processing Record 14 of Set 12 | marawi
# Processing Record 15 of Set 12 | waipawa
# Processing Record 16 of Set 12 | valdemarpils
# Processing Record 17 of Set 12 | grootfontein
# Processing Record 18 of Set 12 | sao gabriel da cachoeira
# Processing Record 19 of Set 12 | cumadcad
# Processing Record 20 of Set 12 | gordeyevka
# Processing Record 21 of Set 12 | jacareacanga
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | cabedelo
# Processing Record 24 of Set 12 | darhan
# Processing Record 25 of Set 12 | sistranda
# Processing Record 26 of Set 12 | kostino
# Processing Record 27 of Set 12 | pangnirtung
# Processing Record 28 of Set 12 | beaufort
# Processing Record 29 of Set 12 | cayenne
# Processing Record 30 of Set 12 | fort nelson
# Processing Record 31 of Set 12 | vathi
# Processing Record 32 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 12 | bundaberg
# Processing Record 34 of Set 12 | sur
# Processing Record 35 of Set 12 | la ronge
# Processing Record 36 of Set 12 | san luis
# Processing Record 37 of Set 12 | shingu
# Processing Record 38 of Set 12 | itarema
# Processing Record 39 of Set 12 | goderich
# Processing Record 40 of Set 12 | roebourne
# Processing Record 41 of Set 12 | bima
# Processing Record 42 of Set 12 | murgab
# Processing Record 43 of Set 12 | tommot
# Processing Record 44 of Set 12 | samarinda
# Processing Record 45 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 12 | buala
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | mandalgovi
# Processing Record 49 of Set 12 | port alfred
# Processing Record 50 of Set 12 | maniitsoq
# Processing Record 1 of Set 13 | verkhoyansk
# Processing Record 2 of Set 13 | huarmey
# Processing Record 3 of Set 13 | villa carlos paz
# Processing Record 4 of Set 13 | piracanjuba
# Processing Record 5 of Set 13 | dumai
# Processing Record 6 of Set 13 | liyang
# Processing Record 7 of Set 13 | oranjestad
# Processing Record 8 of Set 13 | evensk
# Processing Record 9 of Set 13 | orikum
# Processing Record 10 of Set 13 | kochki
# Processing Record 11 of Set 13 | samarai
# Processing Record 12 of Set 13 | navalmoral de la mata
# Processing Record 13 of Set 13 | rocha
# Processing Record 14 of Set 13 | gizo
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 567

# %%
# Convert the array of dictionaries to a df.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.19  168.86     48.18        72          79
# 1   Ozernovskiy      RU  51.50  156.52     46.42        77         100
# 2  San Patricio      MX  19.22 -104.70     84.20        74          20
# 3      Atkinson      US  42.84  -71.15     81.00        57           1
# 4         Cozma      RO  46.81   24.52     63.00        93         100
# 5        Dikson      RU  73.51   80.55     35.55        86           0
# 6       Emerald      AU -23.53  148.17     69.01        60           0
# 7     Ilulissat      GL  69.22  -51.10     51.80        37           0
# 8     Cape Town      ZA -33.93   18.42     61.00        87          75
# 9     Tuatapere      NZ -46.13  167.68     50.97        69          46
#
#    Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 0        1.32                broken clouds            0.0              0
# 1        1.63              overcast clouds            0.0              0
# 2        9.17                   few clouds            0.0              0
# 3        8.05                    clear sky            0.0              0
# 4        3.36  light intensity shower rain            0.0              0
# 5        0.69                    clear sky            0.0              0
# 6        5.82                    clear sky            0.0              0
# 7       17.22                    clear sky            0.0              0
# 8        4.70                broken clouds            0.0              0
# 9        1.05             scattered clouds            0.0              0

# %%
# Create the CSV output file.
output_data_file = "data/WeatherPy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
